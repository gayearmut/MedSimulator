# %% [markdown]
# <a href="https://colab.research.google.com/github/ClesteA/MedSimulator/blob/main/vllmcasegen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. KURULUM (vLLM Engine) ---
# vLLM, şu an dünyadaki en hızlı LLM servis kütüphanesidir.
# !pip install -q vllm

import json
import random
import re
from vllm import LLM, SamplingParams
from huggingface_hub import login
from google.colab import files

# Token Girişi
print("Hugging Face Token Giriniz:")
login()

# --- 2. AYARLAR ---
MODEL_ID = "google/medgemma-27b-text-it"

# A100 80GB olduğu için modeli sıkıştırmadan (bfloat16) yükleyebiliriz.
# Bu en yüksek kaliteyi ve hızı verir.
print(f"\n🚀 vLLM Motoru Başlatılıyor... (Model: {MODEL_ID})")

# GPU Kullanım Ayarları
llm = LLM(
    model=MODEL_ID,
    dtype="bfloat16",       # A100'ün ana dili, en hızlısı
    tensor_parallel_size=1, # Tek GPU kullanıyoruz
    gpu_memory_utilization=0.95, # VRAM'in %95'ini kullan (Yaklaşık 76GB)
    max_model_len=4096,     # Context penceresi
    enforce_eager=True      # CUDA Graph hatasını önlemek için güvenli mod
)

# Üretim Parametreleri
sampling_params = SamplingParams(
    temperature=0.55,
    top_p=0.95,
    max_tokens=2048, # Her vaka için maksimum uzunluk
    stop=["<end_of_turn>"] # Modelin durması gereken yer
)

# --- 3. PROMPT HAZIRLAMA ---
def prompt_olustur(tani):
    return f"""<start_of_turn>user
    Sen klinik simülasyon senaryoları ve vakaları hazırlayan kıdemli bir tıp profesörüsün.

            GÖREV: '{tani}' tanısı için tıp öğrencileri ve doktorları eğitecek zorlukta ve gerçekçilikte bir vaka oluştur. Tutarlılığa maksimum önem ver.

            KRİTİK KURALLAR (Bunlara kesinlikle uy):
            1. **Epidemiyoloji:** Hastanın yaşı ve cinsiyeti, '{tani}' hastalığının gerçek hayattaki insidansına uygun olmalı.
            2. **Dil Ayrımı:** - "sikayet" alanı: Hastanın kendi ağzından, basit, korkmuş bir halk diliyle yazılmalı. (Örn: "Hocam göğsüme bir fil oturdu sanki")
               - Diğer tüm alanlar: Tamamen profesyonel, akademik TIBBİ TERMİNOLOJİ ile yazılmalı.
            3. **Tutarlılık:** Vital bulgular hastalığın şiddetiyle uyumlu olmalı. (Örn: Şok tablosundaysa TA düşük, Nabız yüksek olmalı).
            4. **Laboratuvar:** Sadece patolojik olanları değil, kafa karıştırmak için normal çıkan rutin tetkikleri de listeye ekle. Birimleri (mg/dL vb.) mutlaka yaz.
            5. **Çıktı:** SADECE JSON formatında yanıt ver. Yorum yapma.

            JSON ŞEMASI:
            {{
                "id": "vaka_ID",
                "gizli_tani": "{tani}",
                "hasta_kimlik": {{
                    "ad_soyad": "Rastgele Türk İsmi",
                    "yas": "integer",
                    "cinsiyet": "Erkek/Kadın",
                    "meslek": "Rastgele meslek. Bazen hastalıkla ilişkili uygun meslek de seçilebilir.",
                    "sikayet": "Hastanın ilk cümlesi (Halk ağzı)"
                }},
                "anamnez": {{
                    "sikayet_detaylari": "Tıbbi dille detaylı anamnez (Süre, karakter, yayılım, eşlik eden semptomlar)",
                    "kronik_hastaliklar": "Varsa ek hastalıklar",
                    "kullandigi_ilaclar": "İlaçlar ve dozları",
                    "tibbi_ozgecmis": "Operasyonlar, alerjiler"
                }},
                "bulgular": {{
                    "fizik_muayene": "Sistemik muayene (Genel durum, Vital Bulgular: TA, Nabız, Ateş, SpO2, Solunum sayısı mutlaka olsun)",
                    "laboratuvar": "Kan/İdrar sonuçları (Birimleriyle)",
                    "goruntuleme": "Radyoloji veya EKG rapor sonucu"
                }}
            }}<end_of_turn>
<start_of_turn>model
            """

# --- 4. TOPLU ÜRETİM (BATCH PROCESSING) ---
tanilar = [
    "Akut Pankreatit", "Diyabetik Ketoasidoz (DKA)", "Toplum Kökenli Pnömoni",
    "Akut Piyelonefrit", "Demir Eksikliği Anemisi", "Pulmoner Emboli", "Hipertansif Acil",
    "Kronik Obstrüktif Akciğer Hastalığı (KOAH) Alevlenmesi", "Tansiyonel Pnömotoraks",
    "Subaraknoid Kanama", "Hipokalemi", "Akut Apandisit", "Akut Böbrek Hasarı",
    "Kafa Travması", "Hiponatremi", "Dismenore", "Serebrovasküler Olay (SVO)",
    "Kemik Kırığı", "Akut Glomerülonefrit", "Tirotoksikoz", "Atriyal Fibrilasyon",
    "Akut Astım Atağı", "Perikardit", "Akut Ürtiker", "Supraventriküler Taşikardi (SVT)",
    "Bradikardi", "Ventriküler Taşikardi", "Ventriküler Fibrilasyon", "Hiperkalemi",
    "Akut Pulmoner Ödem", "Akut Karaciğer Yetmezliği", "Akut Menenjit", "Akut Kolanjit",
    "Akut Divertikülit", "Akut Hipotansiyon", "Akut Nazofarenjit (ÜSYE)",
    "Akut Tonsillofarenjit", "Akut Sinüzit", "İnfluenza", "Alerjik Rinit",
    "Miyokard Enfarktüsü (USAP-NSTEMI-STEMI)", "Derin Ven Trombozu", "Gastroözofageal Reflü",
    "Akut Gastrit", "Akut Gastroenterit", "Akut Kolesistit", "Hemoroidal Hastalık",
    "Dislipidemi", "Gut Atağı", "Migren", "Gerilim Tipi Baş Ağrısı", "BPPV",
    "Vestibüler Nörit", "Epilepsi Nöbeti", "Karpal Tünel Sendromu", "Bell Paralizisi",
    "Akut Sistit", "Renal Kolik", "Mekanik Bel Ağrısı", "Lomber Disk Hernisi",
    "Osteoartrit", "Fibromiyalji", "Ayak Bileği Burkulması", "Akut Otitis Media",
    "Akut Otitis Eksterna", "Epistaksis", "Konjonktivit", "Panik Atak", "Anafilaksi",
    "Yanıklar", "Aort Diseksiyonu"
]

# Prompt Listesini Hazırla (Her tanıdan 3 adet)
all_prompts = []
tani_meta = [] # Hangi promptun hangi tanıya ait olduğunu tutar

ADET_BASI = 10

print(f"\n⚡ {len(tanilar) * ADET_BASI} adet vaka için promptlar hazırlanıyor...")
for tani in tanilar:
    for _ in range(ADET_BASI):
        all_prompts.append(prompt_olustur(tani))
        tani_meta.append(tani)

# --- MOTORU ATEŞLE ---
print(f"🔥 BATCH GENERATION BAŞLIYOR... (Arkanıza yaslanın, vLLM A100'ü ağlatacak)")
outputs = llm.generate(all_prompts, sampling_params)

# --- 5. SONUÇLARI İŞLE ---
vaka_veritabani = []
global_sayac = 1

def extract_json_clean(text):
    try:
        text = re.sub(r'```json\s*', '', text)
        text = re.sub(r'```', '', text)
        start = text.find('{')
        end = text.rfind('}') + 1
        if start != -1 and end != -1:
            return json.loads(text[start:end])
    except:
        return None

print("\n✅ Üretim tamamlandı. JSON formatına dönüştürülüyor...")

for i, output in enumerate(outputs):
    generated_text = output.outputs[0].text
    tani_ismi = tani_meta[i]

    data = extract_json_clean(generated_text)

    if data:
        data["id"] = f"vaka_{global_sayac:03d}"
        data["gizli_tani"] = tani_ismi
        vaka_veritabani.append(data)
        global_sayac += 1
    else:
        print(f"⚠️ Format Hatası (Index {i} - {tani_ismi})")

# Karıştır
random.shuffle(vaka_veritabani)

# Kaydet
dosya_adi = "medsim_vllm_ultra_fast.json"
with open(dosya_adi, "w", encoding="utf-8") as f:
    json.dump(vaka_veritabani, f, ensure_ascii=False, indent=4)

print(f"\n🎉 İŞLEM BİTTİ! Toplam {len(vaka_veritabani)} vaka üretildi.")
print(f"Dosya: {dosya_adi}")
files.download(dosya_adi)
# Out:
# Hugging Face Token Giriniz:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# 🚀 vLLM Motoru Başlatılıyor... (Model: google/medgemma-27b-text-it)
# INFO 12-08 12:51:52 [utils.py:253] non-default args: {'dtype': 'bfloat16', 'seed': None, 'max_model_len': 4096, 'gpu_memory_utilization': 0.95, 'disable_log_stats': True, 'enforce_eager': True, 'model': 'google/medgemma-27b-text-it'}
# config.json:   0%|          | 0.00/931 [00:00<?, ?B/s]
# WARNING 12-08 12:51:52 [arg_utils.py:1175] `seed=None` is equivalent to `seed=0` in V1 Engine. You will no longer be allowed to pass `None` in v0.13.
# INFO 12-08 12:52:12 [model.py:637] Resolved architecture: Gemma3ForCausalLM
# INFO 12-08 12:52:12 [model.py:1750] Using max model len 4096
# INFO 12-08 12:52:15 [scheduler.py:228] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 12-08 12:52:15 [vllm.py:601] Enforce eager set, overriding optimization level to -O0
# INFO 12-08 12:52:15 [vllm.py:707] Cudagraph is disabled under eager mode
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# WARNING 12-08 12:52:25 [system_utils.py:136] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# INFO 12-08 12:56:21 [llm.py:343] Supported tasks: ['generate']
#
# ⚡ 710 adet vaka için promptlar hazırlanıyor...
# 🔥 BATCH GENERATION BAŞLIYOR... (Arkanıza yaslanın, vLLM A100'ü ağlatacak)
# Adding requests:   0%|          | 0/710 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/710 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# ✅ Üretim tamamlandı. JSON formatına dönüştürülüyor...
# ⚠️ Format Hatası (Index 0 - Akut Pankreatit)
# ⚠️ Format Hatası (Index 1 - Akut Pankreatit)
# ⚠️ Format Hatası (Index 2 - Akut Pankreatit)
# ⚠️ Format Hatası (Index 3 - Akut Pankreatit)
# ⚠️ Format Hatası (Index 8 - Akut Pankreatit)
# ⚠️ Format Hatası (Index 9 - Akut Pankreatit)
# ⚠️ Format Hatası (Index 10 - Diyabetik Ketoasidoz (DKA))
# ⚠️ Format Hatası (Index 13 - Diyabetik Ketoasidoz (DKA))
# ⚠️ Format Hatası (Index 14 - Diyabetik Ketoasidoz (DKA))
# ⚠️ Format Hatası (Index 20 - Toplum Kökenli Pnömoni)
# ⚠️ Format Hatası (Index 21 - Toplum Kökenli Pnömoni)
# ⚠️ Format Hatası (Index 23 - Toplum Kökenli Pnömoni)
# ⚠️ Format Hatası (Index 27 - Toplum Kökenli Pnömoni)
# ⚠️ Format Hatası (Index 30 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 31 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 32 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 33 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 34 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 35 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 36 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 37 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 39 - Akut Piyelonefrit)
# ⚠️ Format Hatası (Index 44 - Demir Eksikliği Anemisi)
# ⚠️ Format Hatası (Index 45 - Demir Eksikliği Anemisi)
# ⚠️ Format Hatası (Index 46 - Demir Eksikliği Anemisi)
# ⚠️ Format Hatası (Index 47 - Demir Eksikliği Anemisi)
# ⚠️ Format Hatası (Index 48 - Demir Eksikliği Anemisi)
# ⚠️ Format Hatası (Index 53 - Pulmoner Emboli)
# ⚠️ Format Hatası (Index 56 - Pulmoner Emboli)
# ⚠️ Format Hatası (Index 58 - Pulmoner Emboli)
# ⚠️ Format Hatası (Index 59 - Pulmoner Emboli)
# ⚠️ Format Hatası (Index 76 - Kronik Obstrüktif Akciğer Hastalığı (KOAH) Alevlenmesi)
# ⚠️ Format Hatası (Index 77 - Kronik Obstrüktif Akciğer Hastalığı (KOAH) Alevlenmesi)
# ⚠️ Format Hatası (Index 80 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 81 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 82 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 83 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 84 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 85 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 86 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 87 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 88 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 89 - Tansiyonel Pnömotoraks)
# ⚠️ Format Hatası (Index 90 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 91 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 92 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 93 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 95 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 96 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 97 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 98 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 99 - Subaraknoid Kanama)
# ⚠️ Format Hatası (Index 100 - Hipokalemi)
# ⚠️ Format Hatası (Index 105 - Hipokalemi)
# ⚠️ Format Hatası (Index 107 - Hipokalemi)
# ⚠️ Format Hatası (Index 110 - Akut Apandisit)
# ⚠️ Format Hatası (Index 111 - Akut Apandisit)
# ⚠️ Format Hatası (Index 112 - Akut Apandisit)
# ⚠️ Format Hatası (Index 114 - Akut Apandisit)
# ⚠️ Format Hatası (Index 115 - Akut Apandisit)
# ⚠️ Format Hatası (Index 116 - Akut Apandisit)
# ⚠️ Format Hatası (Index 122 - Akut Böbrek Hasarı)
# ⚠️ Format Hatası (Index 127 - Akut Böbrek Hasarı)
# ⚠️ Format Hatası (Index 130 - Kafa Travması)
# ⚠️ Format Hatası (Index 131 - Kafa Travması)
# ⚠️ Format Hatası (Index 132 - Kafa Travması)
# ⚠️ Format Hatası (Index 133 - Kafa Travması)
# ⚠️ Format Hatası (Index 134 - Kafa Travması)
# ⚠️ Format Hatası (Index 135 - Kafa Travması)
# ⚠️ Format Hatası (Index 139 - Kafa Travması)
# ⚠️ Format Hatası (Index 140 - Hiponatremi)
# ⚠️ Format Hatası (Index 150 - Dismenore)
# ⚠️ Format Hatası (Index 151 - Dismenore)
# ⚠️ Format Hatası (Index 152 - Dismenore)
# ⚠️ Format Hatası (Index 153 - Dismenore)
# ⚠️ Format Hatası (Index 154 - Dismenore)
# ⚠️ Format Hatası (Index 155 - Dismenore)
# ⚠️ Format Hatası (Index 156 - Dismenore)
# ⚠️ Format Hatası (Index 157 - Dismenore)
# ⚠️ Format Hatası (Index 158 - Dismenore)
# ⚠️ Format Hatası (Index 159 - Dismenore)
# ⚠️ Format Hatası (Index 161 - Serebrovasküler Olay (SVO))
# ⚠️ Format Hatası (Index 171 - Kemik Kırığı)
# ⚠️ Format Hatası (Index 176 - Kemik Kırığı)
# ⚠️ Format Hatası (Index 181 - Akut Glomerülonefrit)
# ⚠️ Format Hatası (Index 189 - Akut Glomerülonefrit)
# ⚠️ Format Hatası (Index 190 - Tirotoksikoz)
# ⚠️ Format Hatası (Index 191 - Tirotoksikoz)
# ⚠️ Format Hatası (Index 192 - Tirotoksikoz)
# ⚠️ Format Hatası (Index 199 - Tirotoksikoz)
# ⚠️ Format Hatası (Index 200 - Atriyal Fibrilasyon)
# ⚠️ Format Hatası (Index 202 - Atriyal Fibrilasyon)
# ⚠️ Format Hatası (Index 204 - Atriyal Fibrilasyon)
# ⚠️ Format Hatası (Index 205 - Atriyal Fibrilasyon)
# ⚠️ Format Hatası (Index 206 - Atriyal Fibrilasyon)
# ⚠️ Format Hatası (Index 208 - Atriyal Fibrilasyon)
# ⚠️ Format Hatası (Index 211 - Akut Astım Atağı)
# ⚠️ Format Hatası (Index 216 - Akut Astım Atağı)
# ⚠️ Format Hatası (Index 217 - Akut Astım Atağı)
# ⚠️ Format Hatası (Index 220 - Perikardit)
# ⚠️ Format Hatası (Index 221 - Perikardit)
# ⚠️ Format Hatası (Index 222 - Perikardit)
# ⚠️ Format Hatası (Index 223 - Perikardit)
# ⚠️ Format Hatası (Index 224 - Perikardit)
# ⚠️ Format Hatası (Index 225 - Perikardit)
# ⚠️ Format Hatası (Index 226 - Perikardit)
# ⚠️ Format Hatası (Index 228 - Perikardit)
# ⚠️ Format Hatası (Index 229 - Perikardit)
# ⚠️ Format Hatası (Index 230 - Akut Ürtiker)
# ⚠️ Format Hatası (Index 232 - Akut Ürtiker)
# ⚠️ Format Hatası (Index 234 - Akut Ürtiker)
# ⚠️ Format Hatası (Index 240 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 241 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 242 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 243 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 244 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 245 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 246 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 247 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 248 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 249 - Supraventriküler Taşikardi (SVT))
# ⚠️ Format Hatası (Index 251 - Bradikardi)
# ⚠️ Format Hatası (Index 254 - Bradikardi)
# ⚠️ Format Hatası (Index 259 - Bradikardi)
# ⚠️ Format Hatası (Index 261 - Ventriküler Taşikardi)
# ⚠️ Format Hatası (Index 262 - Ventriküler Taşikardi)
# ⚠️ Format Hatası (Index 265 - Ventriküler Taşikardi)
# ⚠️ Format Hatası (Index 266 - Ventriküler Taşikardi)
# ⚠️ Format Hatası (Index 268 - Ventriküler Taşikardi)
# ⚠️ Format Hatası (Index 271 - Ventriküler Fibrilasyon)
# ⚠️ Format Hatası (Index 272 - Ventriküler Fibrilasyon)
# ⚠️ Format Hatası (Index 273 - Ventriküler Fibrilasyon)
# ⚠️ Format Hatası (Index 274 - Ventriküler Fibrilasyon)
# ⚠️ Format Hatası (Index 277 - Ventriküler Fibrilasyon)
# ⚠️ Format Hatası (Index 280 - Hiperkalemi)
# ⚠️ Format Hatası (Index 293 - Akut Pulmoner Ödem)
# ⚠️ Format Hatası (Index 294 - Akut Pulmoner Ödem)
# ⚠️ Format Hatası (Index 298 - Akut Pulmoner Ödem)
# ⚠️ Format Hatası (Index 299 - Akut Pulmoner Ödem)
# ⚠️ Format Hatası (Index 300 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 302 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 303 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 304 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 305 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 307 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 308 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 309 - Akut Karaciğer Yetmezliği)
# ⚠️ Format Hatası (Index 310 - Akut Menenjit)
# ⚠️ Format Hatası (Index 312 - Akut Menenjit)
# ⚠️ Format Hatası (Index 313 - Akut Menenjit)
# ⚠️ Format Hatası (Index 314 - Akut Menenjit)
# ⚠️ Format Hatası (Index 316 - Akut Menenjit)
# ⚠️ Format Hatası (Index 317 - Akut Menenjit)
# ⚠️ Format Hatası (Index 318 - Akut Menenjit)
# ⚠️ Format Hatası (Index 320 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 321 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 322 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 323 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 324 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 325 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 326 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 328 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 329 - Akut Kolanjit)
# ⚠️ Format Hatası (Index 331 - Akut Divertikülit)
# ⚠️ Format Hatası (Index 332 - Akut Divertikülit)
# ⚠️ Format Hatası (Index 333 - Akut Divertikülit)
# ⚠️ Format Hatası (Index 334 - Akut Divertikülit)
# ⚠️ Format Hatası (Index 335 - Akut Divertikülit)
# ⚠️ Format Hatası (Index 338 - Akut Divertikülit)
# ⚠️ Format Hatası (Index 343 - Akut Hipotansiyon)
# ⚠️ Format Hatası (Index 345 - Akut Hipotansiyon)
# ⚠️ Format Hatası (Index 346 - Akut Hipotansiyon)
# ⚠️ Format Hatası (Index 348 - Akut Hipotansiyon)
# ⚠️ Format Hatası (Index 352 - Akut Nazofarenjit (ÜSYE))
# ⚠️ Format Hatası (Index 354 - Akut Nazofarenjit (ÜSYE))
# ⚠️ Format Hatası (Index 357 - Akut Nazofarenjit (ÜSYE))
# ⚠️ Format Hatası (Index 358 - Akut Nazofarenjit (ÜSYE))
# ⚠️ Format Hatası (Index 359 - Akut Nazofarenjit (ÜSYE))
# ⚠️ Format Hatası (Index 360 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 362 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 363 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 364 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 366 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 367 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 368 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 369 - Akut Tonsillofarenjit)
# ⚠️ Format Hatası (Index 372 - Akut Sinüzit)
# ⚠️ Format Hatası (Index 373 - Akut Sinüzit)
# ⚠️ Format Hatası (Index 374 - Akut Sinüzit)
# ⚠️ Format Hatası (Index 377 - Akut Sinüzit)
# ⚠️ Format Hatası (Index 378 - Akut Sinüzit)
# ⚠️ Format Hatası (Index 380 - İnfluenza)
# ⚠️ Format Hatası (Index 381 - İnfluenza)
# ⚠️ Format Hatası (Index 382 - İnfluenza)
# ⚠️ Format Hatası (Index 384 - İnfluenza)
# ⚠️ Format Hatası (Index 387 - İnfluenza)
# ⚠️ Format Hatası (Index 390 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 391 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 392 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 393 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 394 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 395 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 396 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 398 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 399 - Alerjik Rinit)
# ⚠️ Format Hatası (Index 400 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 401 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 403 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 404 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 405 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 406 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 407 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 409 - Miyokard Enfarktüsü (USAP-NSTEMI-STEMI))
# ⚠️ Format Hatası (Index 413 - Derin Ven Trombozu)
# ⚠️ Format Hatası (Index 418 - Derin Ven Trombozu)
# ⚠️ Format Hatası (Index 420 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 421 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 422 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 424 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 425 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 426 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 427 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 428 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 429 - Gastroözofageal Reflü)
# ⚠️ Format Hatası (Index 432 - Akut Gastrit)
# ⚠️ Format Hatası (Index 434 - Akut Gastrit)
# ⚠️ Format Hatası (Index 435 - Akut Gastrit)
# ⚠️ Format Hatası (Index 436 - Akut Gastrit)
# ⚠️ Format Hatası (Index 438 - Akut Gastrit)
# ⚠️ Format Hatası (Index 440 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 441 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 442 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 443 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 444 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 446 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 447 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 448 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 449 - Akut Gastroenterit)
# ⚠️ Format Hatası (Index 450 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 451 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 452 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 453 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 454 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 455 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 456 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 457 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 458 - Akut Kolesistit)
# ⚠️ Format Hatası (Index 460 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 461 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 462 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 463 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 464 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 465 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 466 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 467 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 468 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 469 - Hemoroidal Hastalık)
# ⚠️ Format Hatası (Index 470 - Dislipidemi)
# ⚠️ Format Hatası (Index 473 - Dislipidemi)
# ⚠️ Format Hatası (Index 474 - Dislipidemi)
# ⚠️ Format Hatası (Index 475 - Dislipidemi)
# ⚠️ Format Hatası (Index 476 - Dislipidemi)
# ⚠️ Format Hatası (Index 479 - Dislipidemi)
# ⚠️ Format Hatası (Index 481 - Gut Atağı)
# ⚠️ Format Hatası (Index 483 - Gut Atağı)
# ⚠️ Format Hatası (Index 484 - Gut Atağı)
# ⚠️ Format Hatası (Index 486 - Gut Atağı)
# ⚠️ Format Hatası (Index 487 - Gut Atağı)
# ⚠️ Format Hatası (Index 488 - Gut Atağı)
# ⚠️ Format Hatası (Index 490 - Migren)
# ⚠️ Format Hatası (Index 491 - Migren)
# ⚠️ Format Hatası (Index 492 - Migren)
# ⚠️ Format Hatası (Index 493 - Migren)
# ⚠️ Format Hatası (Index 495 - Migren)
# ⚠️ Format Hatası (Index 497 - Migren)
# ⚠️ Format Hatası (Index 498 - Migren)
# ⚠️ Format Hatası (Index 499 - Migren)
# ⚠️ Format Hatası (Index 500 - Gerilim Tipi Baş Ağrısı)
# ⚠️ Format Hatası (Index 501 - Gerilim Tipi Baş Ağrısı)
# ⚠️ Format Hatası (Index 503 - Gerilim Tipi Baş Ağrısı)
# ⚠️ Format Hatası (Index 506 - Gerilim Tipi Baş Ağrısı)
# ⚠️ Format Hatası (Index 509 - Gerilim Tipi Baş Ağrısı)
# ⚠️ Format Hatası (Index 512 - BPPV)
# ⚠️ Format Hatası (Index 515 - BPPV)
# ⚠️ Format Hatası (Index 516 - BPPV)
# ⚠️ Format Hatası (Index 518 - BPPV)
# ⚠️ Format Hatası (Index 519 - BPPV)
# ⚠️ Format Hatası (Index 520 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 522 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 523 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 524 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 525 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 527 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 528 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 529 - Vestibüler Nörit)
# ⚠️ Format Hatası (Index 530 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 531 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 532 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 534 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 535 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 536 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 538 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 539 - Epilepsi Nöbeti)
# ⚠️ Format Hatası (Index 540 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 541 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 543 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 544 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 545 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 546 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 548 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 549 - Karpal Tünel Sendromu)
# ⚠️ Format Hatası (Index 550 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 551 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 553 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 554 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 555 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 556 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 557 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 558 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 559 - Bell Paralizisi)
# ⚠️ Format Hatası (Index 560 - Akut Sistit)
# ⚠️ Format Hatası (Index 561 - Akut Sistit)
# ⚠️ Format Hatası (Index 562 - Akut Sistit)
# ⚠️ Format Hatası (Index 563 - Akut Sistit)
# ⚠️ Format Hatası (Index 564 - Akut Sistit)
# ⚠️ Format Hatası (Index 565 - Akut Sistit)
# ⚠️ Format Hatası (Index 566 - Akut Sistit)
# ⚠️ Format Hatası (Index 567 - Akut Sistit)
# ⚠️ Format Hatası (Index 568 - Akut Sistit)
# ⚠️ Format Hatası (Index 570 - Renal Kolik)
# ⚠️ Format Hatası (Index 571 - Renal Kolik)
# ⚠️ Format Hatası (Index 572 - Renal Kolik)
# ⚠️ Format Hatası (Index 573 - Renal Kolik)
# ⚠️ Format Hatası (Index 574 - Renal Kolik)
# ⚠️ Format Hatası (Index 575 - Renal Kolik)
# ⚠️ Format Hatası (Index 576 - Renal Kolik)
# ⚠️ Format Hatası (Index 578 - Renal Kolik)
# ⚠️ Format Hatası (Index 579 - Renal Kolik)
# ⚠️ Format Hatası (Index 580 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 581 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 582 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 583 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 585 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 587 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 588 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 589 - Mekanik Bel Ağrısı)
# ⚠️ Format Hatası (Index 590 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 591 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 592 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 593 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 594 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 596 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 597 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 598 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 599 - Lomber Disk Hernisi)
# ⚠️ Format Hatası (Index 602 - Osteoartrit)
# ⚠️ Format Hatası (Index 605 - Osteoartrit)
# ⚠️ Format Hatası (Index 607 - Osteoartrit)
# ⚠️ Format Hatası (Index 608 - Osteoartrit)
# ⚠️ Format Hatası (Index 609 - Osteoartrit)
# ⚠️ Format Hatası (Index 611 - Fibromiyalji)
# ⚠️ Format Hatası (Index 612 - Fibromiyalji)
# ⚠️ Format Hatası (Index 613 - Fibromiyalji)
# ⚠️ Format Hatası (Index 615 - Fibromiyalji)
# ⚠️ Format Hatası (Index 617 - Fibromiyalji)
# ⚠️ Format Hatası (Index 618 - Fibromiyalji)
# ⚠️ Format Hatası (Index 619 - Fibromiyalji)
# ⚠️ Format Hatası (Index 620 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 621 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 622 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 623 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 624 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 625 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 626 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 627 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 628 - Ayak Bileği Burkulması)
# ⚠️ Format Hatası (Index 630 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 631 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 632 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 633 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 634 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 635 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 636 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 637 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 638 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 639 - Akut Otitis Media)
# ⚠️ Format Hatası (Index 640 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 642 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 643 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 645 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 646 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 647 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 648 - Akut Otitis Eksterna)
# ⚠️ Format Hatası (Index 650 - Epistaksis)
# ⚠️ Format Hatası (Index 651 - Epistaksis)
# ⚠️ Format Hatası (Index 653 - Epistaksis)
# ⚠️ Format Hatası (Index 655 - Epistaksis)
# ⚠️ Format Hatası (Index 656 - Epistaksis)
# ⚠️ Format Hatası (Index 658 - Epistaksis)
# ⚠️ Format Hatası (Index 660 - Konjonktivit)
# ⚠️ Format Hatası (Index 661 - Konjonktivit)
# ⚠️ Format Hatası (Index 663 - Konjonktivit)
# ⚠️ Format Hatası (Index 664 - Konjonktivit)
# ⚠️ Format Hatası (Index 665 - Konjonktivit)
# ⚠️ Format Hatası (Index 666 - Konjonktivit)
# ⚠️ Format Hatası (Index 667 - Konjonktivit)
# ⚠️ Format Hatası (Index 668 - Konjonktivit)
# ⚠️ Format Hatası (Index 669 - Konjonktivit)
# ⚠️ Format Hatası (Index 670 - Panik Atak)
# ⚠️ Format Hatası (Index 671 - Panik Atak)
# ⚠️ Format Hatası (Index 672 - Panik Atak)
# ⚠️ Format Hatası (Index 673 - Panik Atak)
# ⚠️ Format Hatası (Index 674 - Panik Atak)
# ⚠️ Format Hatası (Index 676 - Panik Atak)
# ⚠️ Format Hatası (Index 677 - Panik Atak)
# ⚠️ Format Hatası (Index 679 - Panik Atak)
# ⚠️ Format Hatası (Index 680 - Anafilaksi)
# ⚠️ Format Hatası (Index 685 - Anafilaksi)
# ⚠️ Format Hatası (Index 690 - Yanıklar)
# ⚠️ Format Hatası (Index 693 - Yanıklar)
# ⚠️ Format Hatası (Index 694 - Yanıklar)
# ⚠️ Format Hatası (Index 695 - Yanıklar)
# ⚠️ Format Hatası (Index 696 - Yanıklar)
# ⚠️ Format Hatası (Index 699 - Yanıklar)
# ⚠️ Format Hatası (Index 700 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 701 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 702 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 703 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 704 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 705 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 708 - Aort Diseksiyonu)
# ⚠️ Format Hatası (Index 709 - Aort Diseksiyonu)
#
# 🎉 İŞLEM BİTTİ! Toplam 278 vaka üretildi.
# Dosya: medsim_vllm_ultra_fast.json
